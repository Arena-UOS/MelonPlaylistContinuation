# %%
import numpy as np
import pandas as pd
import os
from collections import Counter
from warnings import warn

warn("Unsupported module 'tqdm' is used.")
from tqdm import tqdm


class KNN:

    __version__ = "KNN-1.0"
    
    def __init__(self, k, rho=0.4, alpha=0.5, beta=0.5, \
                 sim_songs="cos", sim_tags="cos", sim_normalize=False, \
                 train=None, val=None, verbose=True, version_check=True):
        '''
        k : int
        rho : float; 0.4(default) only for idf
        alpha, beta : float; 0.5(default)
        sim_songs, sim_tags : "cos"(default), "idf", "jaccard"
        sim_normalize : boolean; when sim == "cos" or "idf"
        verbose : boolean
        '''
        self.train_id = train["id"]
        self.train_songs = train["songs"]
        self.train_tags = train["tags"]
        del train

        self.val_id = val["id"]
        self.val_songs = val["songs"]
        self.val_tags = val["tags"]
        del val

        self.freq_songs = None
        self.freq_tags = None
        
        self.k = k
        self.rho = rho
        self.alpha = alpha
        self.beta = beta

        self.sim_songs = sim_songs
        self.sim_tags = sim_tags
        self.sim_normalize = sim_normalize

        self.verbose = verbose
        self.__version__ = KNN.__version__

        if version_check:
            print(f"KNN version: {KNN.__version__}")

        TOTAL_SONGS = 707989      # total number of songs

        if self.sim_songs == "idf":

            self.freq_songs = np.zeros(TOTAL_SONGS, dtype=np.int64)
            _playlist = self.train_songs
            for _songs in _playlist:
                self.freq_songs[_songs] += 1


    def predict(self, start=0, end=None, auto_save=False, auto_save_step=500, auto_save_fname='auto_save'):
        '''
        start, end : range(start, end). if end = None, range(start, end of val)
        auto_save : boolean; False(default)
        auto_save_step : int; 500(default)
        auto_save_fname : string (without extension); 'auto_save'(default)
        @returns : pandas.DataFrame; columns=['id', 'songs', 'tags']
        '''

        # TODO: Remove unsupported module 'tqdm'.
        if end:
            _range = tqdm(range(start, end)) if self.verbose else range(start, end)
        elif end == None:
            _range = tqdm(range(start, self.val_id.index.stop)) if self.verbose else range(start, self.val_id.index.stop)

        pred = []
        all_songs = [set(songs) for songs in self.train_songs] # list of set
        all_tags =  [set(tags) for tags in self.train_tags]    # list of set

        for uth in _range:

            playlist_songs = set(self.val_songs[uth])
            playlist_tags = set(self.val_tags[uth])
            k = self.k

            if len(playlist_songs) == 0 or self.alpha == 0:
                simSongs = np.zeros(len(all_songs))
            else:
                simSongs = np.array([self._sim(playlist_songs, vplaylist, self.sim_songs, opt="songs") for vplaylist in all_songs])

            if len(playlist_tags) == 0 or self.beta == 0:
                simTags = np.zeros(len(all_tags))
            else:
                simTags = np.array([self._sim(playlist_tags, vplaylist, self.sim_tags, opt="tags") for vplaylist in all_tags])
            
            # TODO: normalize simSongs and simTags
            sim_score = (self.alpha * simSongs) + (self.beta * simTags)

            songs = set()
            tags = []

            # TODO: add condition (len(tags) < 10)
            while (len(songs) < 100 or len(tags)):
                top = sim_score.argsort()[-k:] # top k indicies of playlists in train

                _songs = []
                _tags = []

                # for vth playlist in train
                for vth in top:
                    _songs += self.train_songs[vth]
                    _tags += self.train_tags[vth]
                songs = set(_songs) - playlist_songs

                counts = Counter(_tags).most_common(30)
                tags = [tag for tag, _ in counts if tag not in playlist_tags]
                
                k += 100
            
            norm = sim_score[top].sum()
            if norm == 0:
                norm = 1.0e+10 # FIXME
            
            relevance = np.array([(song, np.sum([simSongs[vth] if song in all_songs[vth] else 0 for vth in top]) / norm) for song in songs])
            relevance = relevance[relevance[:, 1].argsort()][-100:][::-1]
            pred_songs = relevance[:, 0].astype(np.int64).tolist()
            pred_tags = tags[:10]

            pred.append({
                "id" : int(self.val_id[uth]),
                "songs" : pred_songs,
                "tags" : pred_tags
            })

            if (auto_save == True) and ((uth + 1) % auto_save_step == 0):
                self._auto_save(pred, auto_save_fname)
        
        return pd.DataFrame(pred)
    

    def _sim(self, u, v, sim, opt):
        '''
        u : set (playlist in train data)
        v : set (playlist in test data)
        sim : string; "cos", "idf", "jaccard" (kind of similarity)
        opt : string; "songs", "tags"
        '''

        if sim == "cos":
            if self.sim_normalize:
                try:
                    len(u & v) / ((len(u) ** 0.5) * (len(v) ** 0.5))
                except:
                    return 0
            else:
                return len(u & v)
        
        elif sim == "idf":
            if opt == "songs":
                freq = self.freq_songs
            elif opt == "tags":
                freq = self.freq_tags
            freq = freq[list(u & v)]
            freq = 1 / (((freq - 1) ** self.rho) + 1) # numpy!
            if self.sim_normalize:
                try:
                    return freq.sum() / ((len(u) ** 0.5) * (len(v) ** 0.5))
                except:
                    return 0
            else:
                return freq.sum()
        
        elif sim == "jaccard":
            return len(u & v) / len(u | v)
    
    def _auto_save(self, pred, auto_save_fname):
        '''
        pred : list of dictionaries
        auto_save_fname : string
        '''
        
        if not os.path.isdir("./_temp"):
            os.mkdir('./_temp')
        pd.DataFrame(pred).to_json(f'_temp/{auto_save_fname}.json', orient='records')


if __name__=="__main__":

    ### 1. load data
    train = pd.read_json("train.json")
    val = pd.read_json("val.json")
    # test = pd.read_json("res/test.json")

    ### 2. modeling
    ### 2.1 hyperparameters: k, rho, alpha, beta
    ### 2.2 parameters: sim_songs, sim_tags, sim_normalize
    k = 100
    rho = 0.4
    alpha = 0.6
    beta = 0.4
    sim_songs = "idf"
    sim_tags = "cos"
    sim_normalize = False

    ### 3. range setting - KNN.predict()
    ### 3.1 range(start, end); if end == None, then range(start, end of val)
    ### 3.2 auto_save: boolean; False(default)
    ### 3.3 return type of KNN.predict() : pandas.DataFrame
    pred = KNN(k=k, rho=rho, alpha=alpha, beta=beta, 
               sim_songs=sim_songs, sim_tags=sim_tags, sim_normalize=sim_normalize, 
               train=train, val=val, verbose=True, version_check=True).predict(start=0, end=len(val), auto_save=False)
    # print(pred)

    ### 4. save data
    version = KNN.__version__
    version = version[version.find('-') + 1: version.find('.')]
    path = "."
    fname = f"knn{version}_k{k}rho{int(rho * 10)}a{int(alpha * 10)}b{int(beta * 10)}_{sim_songs}{sim_tags}{sim_normalize}"
    pred.to_json(f'{path}/{fname}.json', orient='records')
# Out:
# F:\sda\envs\dlstudy\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Unsupported module 'tqdm' is used.
#   import sys
# KNN version: KNN-1.0
#   0%|                                                                                        | 0/23015 [00:00<?, ?it/s]

# %%
import pandas as pd
val_song0= pd.read_json("val_song0_predictag.json", encoding = 'utf-8')

# %%
val_song0.reset_index(inplace = True)

# %%
val_song0.to_json("val_title.json")

# %%
val_song0
# Out:
#            id  like_cnt                          plylst_title songs  \
# 1      131447         1                                앨리스테이블    []
# 10003  112033         8             제목입으로 먹으면 살찌니까 귀로 먹어요 푸드송    []
# 10006   70866         2                          랩그것은 인생의 진리지    []
# 10012   74889         8         자신이 고음 좀 올라간다 그렇다면 도전해보세요 여자편    []
# 10019   38058        24                      바흐의 피아노 작품집 Vol1    []
# 1003    31976        25              추억 속 강변가요제 수상곡들 19882001    []
# 10033   51678      6138                        밤 산책하며 듣는 감성힙합    []
# 10035   70939         0                                  탑골공원    []
# 10036  110880         9                    여름휴가에 데리고 가면 좋을 노래    []
# 10038   15308        20                           레어블랙뮤직Vol24    []
# 10043   35117        18                             리듬 좀 타볼까     []
# 10047  128240         0                     새벽에 센치해 질 때 듣는 노래    []
# 10051  123005        42                        몽환적트렌디 감성 느껴보자    []
# 10054  130552         4                      이제 겨울이다 캐롤 송 듣자     []
# 10055  150713         5                            크리스마스는 음악과    []
# 10062   84870        82                                달콤한 유혹    []
# 10065   79133       167              빌보드 Hot100 2월 2주차 top100    []
# 10069  150592        15             가을에 한강에서 돗자리깔고 누워서 들으면 핵꿀    []
# 10076   16153         1                          친구 한페이지가될수있게    []
# 10081   20311         5                            클럽음악 건들지마라    []
# 10083   50513         7                 적당히 추억할수 있을때 듣는 감성발라드    []
# 10084   84754         3                              매력적인 edm    []
# 10087   52151       203         달려라 달려 선선한 가을 날씨에 즐기는 자전거 라이딩    []
# 10099  149919         5           비올 때 혼자 내 마음까지 촉촉해지는 좋은 음악들    []
# 101     85920         0                          새벽에 감성 돋는 노래    []
# 1010     1543         1             추운 겨울 밤 지친 하루의 당신을 달래줄 뮤직    []
# 10104   85006         2                           Goin Stupid    []
# 10111   73190         0                            lallalasla    []
# 10115  103489         2                                  밤밤밤에    []
# 10120  104619         8                              성아의 뉴에이지    []
# ...       ...       ...                                   ...   ...
# 9880    20994       293       wCloud List fill Ur heart Souls    []
# 989     61648        24                   마니아들의 언더그라운드 싸이 트랜스    []
# 9890    42050       129                   우리아이가 행복해지는 피아노 클래식    []
# 9898    88670        79                밤성가득한 새벽에 여유롭게 듣는 재즈팝송    []
# 9899     5431        25                           친구라서 하지 못한말    []
# 9901    76179        32  90s 한국 New Jack Swing Jill Swing 콜렉숀    []
# 9907    40749         2                             서쪽에서우는꾀꼬리    []
# 9909    24106       335                  떡떡대는 클럽음악이 부담스러운 당신께    []
# 9910    38878        60                      소녀감성 가득 달콤한 카페뮤직    []
# 9913   109513        25            이런 노래 틀어주는 어린이집으로 우리아이 보내자    []
# 9916    20885        13           PoP 조금띵곡 모음dd 예전곡신규곡 간간히 업뎃    []
# 9918    18686         9                           즐겨듣는 완소 재즈곡    []
# 9920    88443         9                        감성폭발 듣기좋은 노래모음    []
# 9929    49233        20                          잔잔하고 부드러운 RB    []
# 9930    46647        16                  영혼을 달래는 아름다운 피아노 클래식    []
# 9931    35565        14                   편안한 휴식을 위한 잔잔한 연주곡들    []
# 9934   124257        21                              가슴울리는발라드    []
# 9938    79866         0                여름 당신을위한새콤달콤SummerSong    []
# 9946    78986        16                Volume Up 주말을 위한 댄스 뮤직    []
# 9949   140611        29                   새벽 조용히 듣기 좋은 EDMPOP    []
# 995     38311        29                        메타 1티어의 요즘 래퍼들    []
# 9953    40677         1                       피곤함을 날려줄 따스한 연주    []
# 9955    88065         9                     치즈 컴백 기념 치즈 명곡 모음    []
# 9957    32230       115                              싸이월드 BGM    []
# 996     18862         2   아직 조금 쌀쌀한 기운이 남아있는 겨울을 보내며 듣는 감성발라드    []
# 9963   123869       417                 선선한 가을저녁엔 딥한 남성보컬 POP    []
# 9969   153366        23                     Groovy Everywhere    []
# 9976    68661         3                        마음을 움직이는 힙합 모음    []
# 9990   122514        30                  90년대 여자 솔로가수 노래 BEST    []
# 9994    54494        18                    힙합이대세 외국힙합 올드힙합명곡만    []
#
#                                      tags                updt_date  \
# 1                                      []  2014-07-16 15:24:24.000
# 10003                              [기분전환]  2016-11-02 20:27:53.000
# 10006                                [힙합]  2015-10-13 17:02:54.000
# 10012                                  []  2016-02-05 20:43:41.000
# 10019                                  []  2015-04-08 23:24:23.000
# 1003                                 [가요]  2017-01-13 16:05:25.000
# 10033                             [밤, 새벽]  2020-04-18 12:27:54.000
# 10035                                [틀딱]  2019-09-02 12:03:58.000
# 10036                                  []  2016-07-27 21:56:26.000
# 10038                      [HipHop, soul]  2020-03-05 23:28:46.000
# 10043                               [알앤비]  2009-02-26 13:09:18.000
# 10047                                [새벽]  2019-12-02 20:29:55.000
# 10051                [감성, Pop, 그루비한, 트렌디]  2018-03-10 13:47:14.000
# 10054                                [캐롤]  2017-12-13 17:13:05.000
# 10055                                  []  2018-11-29 15:24:14.000
# 10062                              [스트레스]  2014-07-03 11:39:12.000
# 10065                                  []  2015-11-12 16:22:17.000
# 10069                                [여행]  2015-09-25 16:20:50.000
# 10076                          [친구사이, 베프]  2020-04-03 03:31:23.000
# 10081                                  []  2013-10-17 09:08:41.000
# 10083              [편안, 카페, 추억, 포근한, 발라드]  2020-04-22 18:05:42.000
# 10084                                  []  2017-04-22 13:54:44.000
# 10087                     [햇살, 가을, 팝, 인디]  2018-11-15 22:32:14.000
# 10099                    [새벽감성, 감성폭발, 감성]  2020-04-17 22:52:17.000
# 101                                    []  2019-09-05 20:53:20.000
# 1010                [겨울, 느낌적인느낌, 댄스, 오늘밤]  2018-01-08 19:33:52.000
# 10104                                 [랩]  2016-07-13 00:11:04.000
# 10111                                  []  2020-04-16 13:50:09.000
# 10115                                  []  2017-04-09 15:00:56.000
# 10120                                  []  2009-10-26 22:14:44.000
# ...                                   ...                      ...
# 9880                                   []  2016-07-04 03:38:27.000
# 989      [electronica, 몽환, 파티, 파워풀, 스트레스]  2019-12-18 15:02:12.000
# 9890                       [피아노, 힐링, 자장가]  2017-08-21 10:11:30.000
# 9898                            [RnB, 밤성]  2018-06-20 03:27:08.000
# 9899                                 [가을]  2018-03-12 10:36:26.000
# 9901       [인기가요, 뉴잭스윙, 한국, Newjackswing]  2017-04-24 02:41:07.000
# 9907                                   []  2010-10-25 20:54:31.000
# 9909                                   []  2014-02-20 22:27:21.000
# 9910                                 [카페]  2017-05-30 10:05:15.000
# 9913                     [동심, 키즈클럽, 키즈카페]  2016-12-11 19:55:23.000
# 9916                                   []  2019-10-22 21:14:14.000
# 9918                         [재즈, 평소, 갠소]  2017-05-21 14:24:50.000
# 9920                                   []  2019-01-17 13:20:16.000
# 9929                                 [소울]  2011-01-09 03:59:35.000
# 9930   [스트레스해소힐링클래식, 클래식, 피아노클래식, 자장가클래식]  2020-04-06 16:06:56.000
# 9931                                   []  2017-03-17 15:31:22.000
# 9934                                   []  2011-03-31 10:03:34.000
# 9938                                   []  2014-07-03 18:44:10.000
# 9946                                   []  2012-11-09 11:38:08.000
# 9949                                 [새벽]  2016-02-27 22:43:00.000
# 995                                  [외힙]  2017-11-10 13:49:17.000
# 9953             [휴식, 힐링, 지친다, 기분전환, 퇴근길]  2020-04-09 07:07:53.000
# 9955                    [치즈, 꼬롱취향, 무조건좋음]  2018-01-29 17:27:58.000
# 9957                                 [추억]  2018-04-30 11:06:27.000
# 996                          [새벽, 센치, 이별]  2019-03-22 10:30:24.000
# 9963               [감성, 가을, 저녁, 트렌디, 퇴근길]  2020-01-30 14:58:37.000
# 9969                         [GroovyRoom]  2018-03-08 09:58:18.000
# 9976                                   []  2019-04-16 10:14:58.000
# 9990                             [사랑, 회상]  2016-05-27 11:46:08.000
# 9994                                   []  2017-06-29 14:26:42.000
#
#                                               lower_tags
# 1                                                     []
# 10003                                     [푸드송, 귀, 기분전환]
# 10006                                       [힙합, 랩, 인생의]
# 10012                                    [자신, 고음, 도전, 좀]
# 10019                                       [바흐, 피아노, 1]
# 1003                                [수상곡, 추억, 가요, 강변가요제]
# 10033                              [밤, 산책, 듣는, 새벽, 감성힙합]
# 10035                                         [탑골공원, 틀딱]
# 10036                                   [여름, 노래, 휴가, 가면]
# 10038                                 [soul, hiphop, 뮤직]
# 10043                                       [알앤비, 리듬, 좀]
# 10047                             [새벽에, 노래, 듣는, 새벽, 센치해]
# 10051                           [감성, 몽환, pop, 트렌디, 그루비한]
# 10054                                [송, 겨울, 캐롤, 듣자, 이제]
# 10055                                       [크리스마스는, 음악]
# 10062                                    [달콤한, 유혹, 스트레스]
# 10065                       [빌보드, hot100, top100, 2월, 2]
# 10069                          [여행, 들으면, 누워서, 가을에, 한강에서]
# 10076                                 [친구, 베프, 친구사이, 이지]
# 10081                                             [클럽음악]
# 10083          [감성발라드, 카페, 편안, 듣는, 있을때, 포근한, 발라드, 수, 추억]
# 10084                                        [매력적인, edm]
# 10087   [선선한, 햇살, 즐기는, 팝, 날씨, 인디, 달려, 가을, 달려라, 라이딩, 자전거]
# 10099               [음악들, 감성, 마음, 내, 혼자, 새벽감성, 감성폭발, 좋은]
# 101                                        [감성, 노래, 새벽에]
# 1010      [느낌적인느낌, 밤, 뮤직, 댄스, 오늘밤, 하루의, 지친, 추운, 당신을, 겨울]
# 10104                                                [랩]
# 10111                                                 []
# 10115                                                [밤]
# 10120                                             [뉴에이지]
# ...                                                  ...
# 9880                                       [heart, list]
# 989    [싸이, 언더그라운드, 몽환, 스트레스, electronica, 트랜스, 파워풀, 파티]
# 9890                    [아, 피아노, 이, 행복해지는, 클래식, 힐링, 자장가]
# 9898                    [rnb, 재즈, 새벽에, 밤성, 듣는, 팝송, 여유롭게]
# 9899                                        [친구, 가을, 하지]
# 9901     [뉴잭스윙, 인기가요, 90s, swing, new, 한국, newjackswing]
# 9907                                                 [우]
# 9909                                              [클럽음악]
# 9910                           [카페뮤직, 가득, 카페, 달콤한, 소녀감성]
# 9913                [동심, 노래, 키즈카페, 어린이집, 우리아이, 키즈클럽, 이런]
# 9916                               [띵곡, pop, 예전, 모음, 업뎃]
# 9918                         [재즈, 완소, 갠소, 평소, 재즈곡, 즐겨듣는]
# 9920                                  [듣기좋은, 노래모음, 감성폭발]
# 9929                                [소울, 잔잔하고, rb, 부드러운]
# 9930   [피아노, 피아노클래식, 스트레스해소힐링클래식, 클래식, 아름다운, 자장가클래식, 영혼]
# 9931                           [위한, 연주곡들, 잔잔한, 편안한, 휴식을]
# 9934                                           [발라드, 가슴]
# 9938                                                [여름]
# 9946                               [위한, 뮤직, up, 댄스, 주말을]
# 9949                           [edmpop, 듣기, 좋은, 새벽, 조용히]
# 995                                          [요즘, 1, 외힙]
# 9953             [피곤함을, 휴식, 연주, 지친다, 퇴근길, 힐링, 기분전환, 따스한]
# 9955                   [무조건좋음, 꼬롱취향, 치즈, 기념, 명곡, 모음, 컴백]
# 9957                                     [추억, bgm, 싸이월드]
# 996            [감성발라드, 센치, 쌀쌀한, 듣는, 기운, 이별, 아직, 새벽, 겨울을]
# 9963    [선선한, 감성, pop, 가을, 트렌디, 퇴근길, 저녁, 가을저녁, 딥한, 남성보컬]
# 9969                    [groovy, everywhere, groovyroom]
# 9976                                       [마음을, 힙합, 모음]
# 9990                  [90년대, best, 노래, 여자, 회상, 솔로가수, 사랑]
# 9994                                [힙합, 외국힙합, 올드, 힙합명곡]
#
# [4379 rows x 7 columns]
